# %%
import pandas as pd

# %%
def get_allele(allel_xls):
    with open(allel_xls, "r") as file:
        first_line = file.readline()
        allele=re.sub(r"\t|\n", "", first_line)
    return allele

# %%
## reshape dataframe and save
df = pd.read_csv("netMHCpan_out/HLAA0101.xls",sep="\t",skiprows=1)
allele=get_allele(args.input)
df['allele']=allele
# Out:
#         Pos      Peptide               ID       core        icore  EL-score  \
# 0         0  MDLPILKTNAI  KF826828-A-2004  MDLPKTNAI  MDLPILKTNAI    0.0005
# 1         1  DLPILKTNAIT  KF826828-A-2004  DLPKTNAIT  DLPILKTNAIT    0.0000
# 2         2  LPILKTNAITA  KF826828-A-2004  LPILKTNTA  LPILKTNAITA    0.0001
# 3         3  PILKTNAITAI  KF826828-A-2004  PILKTNTAI  PILKTNAITAI    0.0000
# 4         4  ILKTNAITAIL  KF826828-A-2004  ITNAITAIL  ILKTNAITAIL    0.0002
# ...     ...          ...              ...        ...          ...       ...
# 920629  562     QLSGINNI  RSVA_pda_ancest  QLS-GINNI     QLSGINNI    0.0004
# 920630  563     LSGINNIA  RSVA_pda_ancest  LS-GINNIA     LSGINNIA    0.0001
# 920631  564     SGINNIAF  RSVA_pda_ancest  SGI-NNIAF     SGINNIAF    0.0004
# 920632  565     GINNIAFS  RSVA_pda_ancest  GINNIAFS-     GINNIAFS    0.0001
# 920633  566     INNIAFSN  RSVA_pda_ancest  INNIAFSN-     INNIAFSN    0.0000
#
#         EL_Rank     Ave  NB
# ...
