# %%
import pandas as pd
import numpy as np
import sys
from scipy.spatial.distance import cityblock
from progressbar import ProgressBar

# %%
def core_tcrf(core):
    core_tcrf = f'___{core[3]}{core[4]}{core[5]}{core[6]}{core[7]}_'
    return core_tcrf

# %%
## input is the netMPHpan xlsx for multiple sequence but single allel
## for single allel, load the xls file and filter by cutoff
netMHCpan_out="netMHCpan_out copy/RSVA_F_test.xls"
data = pd.read_csv(netMHCpan_out,sep="\t",skiprows=0)
## get core position
# Out:
#          Pos      Peptide               ID       core        icore  EL-score  \
# 22        22  ASSQNITEEFY  KF826828-A-2004  ASSQTEEFY  ASSQNITEEFY    0.5147
# 33        33  QSTCSAVSKGY  KF826828-A-2004  QSSAVSKGY  QSTCSAVSKGY    0.0916
# 187      187  LTSKVLDLKNY  KF826828-A-2004  LTSKVLDLY  LTSKVLDLKNY    0.3065
# 239      239  NAGVTTPVSTY  KF826828-A-2004  NATTPVSTY  NAGVTTPVSTY    0.0786
# 288      288  MSIIKEEVLAY  KF826828-A-2004  MSIEEVLAY  MSIIKEEVLAY    0.2965
# ...      ...          ...              ...        ...          ...       ...
# 5523156  485    DEFDASISQ  RSVA_pda_ancest  DEFDASISQ    DEFDASISQ    0.0393
# 5523167  496    EKINQSLAF  RSVA_pda_ancest  EKINQSLAF    EKINQSLAF    0.0541
# 5523346  109     ELPRFMNY  RSVA_pda_ancest  -ELPRFMNY     ELPRFMNY    0.0467
# 5523707  470     GEPIINFY  RSVA_pda_ancest  GE-PIINFY     GEPIINFY    0.4345
# 5523732  495     NEKINQSL  RSVA_pda_ancest  NEK-INQSL     NEKINQSL    0.0901
#
#          EL_Rank     Ave  NB
# 22        0.2796  0.5147   1
# 33        1.3607  0.0916   1
# 187       0.5307  0.3065   1
# 239       1.5013  0.0786   1
# 288       0.5475  0.2965   1
# ...          ...     ...  ..
# 5523156   1.8983  0.0393   1
# 5523167   1.6067  0.0541   1
# 5523346   1.7353  0.0467   1
# 5523707   0.4193  0.4345   1
# 5523732   1.2304  0.0901   1
#
# [110627 rows x 9 columns]

# %%
df_epitope['core_tcrf'] = df_epitope.apply(lambda x:core_tcrf(x['core']),axis=1)

df_epitope
# Out:
# /Users/jianichen1/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          Pos      Peptide               ID       core        icore  EL-score  \
# 22        22  ASSQNITEEFY  KF826828-A-2004  ASSQTEEFY  ASSQNITEEFY    0.5147
# 33        33  QSTCSAVSKGY  KF826828-A-2004  QSSAVSKGY  QSTCSAVSKGY    0.0916
# 187      187  LTSKVLDLKNY  KF826828-A-2004  LTSKVLDLY  LTSKVLDLKNY    0.3065
# 239      239  NAGVTTPVSTY  KF826828-A-2004  NATTPVSTY  NAGVTTPVSTY    0.0786
# 288      288  MSIIKEEVLAY  KF826828-A-2004  MSIEEVLAY  MSIIKEEVLAY    0.2965
# ...      ...          ...              ...        ...          ...       ...
# 5523156  485    DEFDASISQ  RSVA_pda_ancest  DEFDASISQ    DEFDASISQ    0.0393
# 5523167  496    EKINQSLAF  RSVA_pda_ancest  EKINQSLAF    EKINQSLAF    0.0541
# 5523346  109     ELPRFMNY  RSVA_pda_ancest  -ELPRFMNY     ELPRFMNY    0.0467
# 5523707  470     GEPIINFY  RSVA_pda_ancest  GE-PIINFY     GEPIINFY    0.4345
# 5523732  495     NEKINQSL  RSVA_pda_ancest  NEK-INQSL     NEKINQSL    0.0901
#
#          EL_Rank     Ave  NB  core_tcrf
# 22        0.2796  0.5147   1  ___QTEEF_
# 33        1.3607  0.0916   1  ___AVSKG_
# 187       0.5307  0.3065   1  ___KVLDL_
# 239       1.5013  0.0786   1  ___TPVST_
# 288       0.5475  0.2965   1  ___EEVLA_
# ...          ...     ...  ..        ...
# 5523156   1.8983  0.0393   1  ___DASIS_
# 5523167   1.6067  0.0541   1  ___NQSLA_
# 5523346   1.7353  0.0467   1  ___PRFMN_
# 5523707   0.4193  0.4345   1  ___PIINF_
# 5523732   1.2304  0.0901   1  ___-INQS_
#
# [110627 rows x 10 columns]

# %%
df_epitope = df_epitope[["ID","Pos", "core_tcrf","EL-score"]]
df_epitope
# Out:
#                       ID  Pos  core_tcrf  EL-score
# 22       KF826828-A-2004   22  ___QTEEF_    0.5147
# 33       KF826828-A-2004   33  ___AVSKG_    0.0916
# 187      KF826828-A-2004  187  ___KVLDL_    0.3065
# 239      KF826828-A-2004  239  ___TPVST_    0.0786
# 288      KF826828-A-2004  288  ___EEVLA_    0.2965
# ...                  ...  ...        ...       ...
# 5523156  RSVA_pda_ancest  485  ___DASIS_    0.0393
# 5523167  RSVA_pda_ancest  496  ___NQSLA_    0.0541
# 5523346  RSVA_pda_ancest  109  ___PRFMN_    0.0467
# 5523707  RSVA_pda_ancest  470  ___PIINF_    0.4345
# 5523732  RSVA_pda_ancest  495  ___-INQS_    0.0901
#
# [110627 rows x 4 columns]

# %%
## groupby and calculate sum to see 
df_epitope=df_epitope.groupby(["ID","Pos", "core_tcrf"])["EL-score"].sum().reset_index()
df_epitope
# Out:
#                     ID  Pos  core_tcrf  EL-score
# 0      AB848369-A-2013    0  ___LKTNA_    0.1255
# 1      AB848369-A-2013    0  ___PILKT_    0.0949
# 2      AB848369-A-2013    2  ___LKTNA_    0.8487
# 3      AB848369-A-2013    6  ___AITTI_    0.0769
# 4      AB848369-A-2013    9  ___TILAA_    0.4403
# ...                ...  ...        ...       ...
# 97963  U63644_vaccine_  550  ___STPVT_    0.8511
# 97964  U63644_vaccine_  551  ___PVTLS_    0.7203
# 97965  U63644_vaccine_  552  ___PVTLS_    1.1453
# 97966  U63644_vaccine_  553  ___PVTLS_    0.3141
# 97967  U63644_vaccine_  554  ___TLSKQ_    0.2974
#
# [97968 rows x 4 columns]

# %%
#https://www.statology.org/manhattan-distance-python/
# use mahattan distance to see what happens?    
## reshape dataframe
epitope_feature = df_epitope.pivot_table(index=['core_tcrf'], columns=['ID'],values="EL-score")
epitope_feature = epitope_feature.fillna(0)
## calculate mahatton distance

epitope_feature
# Out:
# ID         AB848369-A-2013  AB848370-A-2012  AB848373-A-2013  AF013255_vaccin  \
# core_tcrf
# ___-AKVK_           0.3448           0.0000           0.0000           0.0000
# ___-CKVQ_           0.0000           0.0000           0.0000           0.0000
# ___-GKNL_           0.0000           0.0000           0.0000           0.1184
# ___-GKSL_           0.0000           0.0000           0.0000           0.0000
# ___-GNTL_           0.1002           0.1002           0.1002           0.1002
# ...                    ...              ...              ...              ...
# ___YTPNN_           0.0000           0.0000           0.0000           0.0000
# ___YVNKK_           0.0000           0.0000           0.0000           0.0000
# ___YVNKQ_           0.3726           0.3726           0.3726           0.0000
# ___YYDPL_           0.0000           0.0000           0.0000           0.1771
# ___YYVNK_           0.0000           0.0000           0.0000           0.0000
#
# ID         AF035006_vaccin  FJ948820-A-1999  JF714709-A-2008  JF714710-A-2009  \
# core_tcrf
# ___-AKVK_           0.0000           0.0000           0.0000           0.0000
# ___-CKVQ_           0.0000           0.0000           0.0000           0.0000
# ___-GKNL_           0.0000           0.0000           0.0000           0.0000
# ___-GKSL_           0.0000           0.0000           0.0000           0.0000
# ___-GNTL_           0.1002           0.1002           0.1002           0.1002
# ...                    ...              ...              ...              ...
# ___YTPNN_           0.0000           0.0000           0.0000           0.0000
# ___YVNKK_           0.0000           0.0000           0.0000           0.0000
# ___YVNKQ_           0.3726           0.3726           0.3726           0.3726
# ___YYDPL_           0.0000           0.0000           0.0000           0.0000
# ___YYVNK_           0.0000           0.0000           0.0000           0.0000
#
# ID         JF920046-A-2007  JF920047-A-2008  ...  MN310477-A-2018  \
# core_tcrf                                    ...
# ___-AKVK_           0.0000           0.0000  ...           0.0000
# ___-CKVQ_           0.0000           0.0000  ...           0.0000
# ___-GKNL_           0.0000           0.0000  ...           0.0000
# ___-GKSL_           0.0000           0.0000  ...           0.0000
# ___-GNTL_           0.1002           0.1002  ...           0.1002
# ...                    ...              ...  ...              ...
# ___YTPNN_           0.0000           0.0000  ...           0.0000
# ___YVNKK_           0.0000           0.0000  ...           0.0000
# ___YVNKQ_           0.3726           0.3726  ...           0.3726
# ___YYDPL_           0.0000           0.0000  ...           0.0000
# ___YYVNK_           0.0000           0.0000  ...           0.0000
#
# ID         MN630091-A-2016  MN630097-A-2016  MN630105-A-2016  MT422269-A-2019  \
# core_tcrf
# ___-AKVK_           0.0000           0.0000           0.0000           0.0000
# ___-CKVQ_           0.0000           0.0000           0.0000           0.0000
# ___-GKNL_           0.0000           0.0000           0.0000           0.0000
# ___-GKSL_           0.0000           0.0000           0.0000           0.0000
# ___-GNTL_           0.1002           0.1002           0.1002           0.1002
# ...                    ...              ...              ...              ...
# ___YTPNN_           0.0000           0.0000           0.0000           0.0000
# ___YVNKK_           0.0000           0.0000           0.0000           0.0000
# ___YVNKQ_           0.3726           0.3726           0.3726           0.3726
# ___YYDPL_           0.0000           0.0000           0.0000           0.0000
# ___YYVNK_           0.0000           0.0000           0.0000           0.0000
#
# ID         MT422270-A-2019  MT422273-A-2019  RSVA_pda_ancest  RSVB_pda_ancest  \
# core_tcrf
# ___-AKVK_           0.0000           0.0000           0.0000           0.0000
# ___-CKVQ_           0.0000           0.0000           0.0000           0.0000
# ___-GKNL_           0.0000           0.0000           0.0000           0.1184
# ___-GKSL_           0.0000           0.0000           0.0000           0.0000
# ___-GNTL_           0.1002           0.1002           0.1002           0.1002
# ...                    ...              ...              ...              ...
# ___YTPNN_           0.0000           0.0000           0.0000           0.0000
# ___YVNKK_           0.0000           0.0000           0.0000           0.0000
# ___YVNKQ_           0.3726           0.3726           0.3726           0.0000
# ___YYDPL_           0.0000           0.0000           0.0000           0.1771
# ___YYVNK_           0.0000           0.0000           0.0000           0.0000
#
# ID         U63644_vaccine_
# core_tcrf
# ___-AKVK_           0.0000
# ___-CKVQ_           0.0000
# ___-GKNL_           0.0000
# ___-GKSL_           0.0000
# ___-GNTL_           0.1002
# ...                    ...
# ___YTPNN_           0.0000
# ___YVNKK_           0.0000
# ___YVNKQ_           0.3726
# ___YYDPL_           0.0000
# ___YYVNK_           0.0000
#
# [661 rows x 407 columns]

# %%
epitope_feature.to_csv("epitope_feature_test.csv",index=False)

# %%
## get sequence ID
seq = df_epitope.ID.unique()
seq
pbar = ProgressBar()
## loop through all seq in seq array to calculate Manhatton distance
seq_distance=[]
for i in pbar(range(len(seq))):
    for j in range(len(seq)):
        if i<j:
            distance = cityblock(epitope_feature[seq[i]], epitope_feature[seq[j]])
            seq_distance.append([seq[i], seq[j], distance])                
            df_distance = pd.DataFrame(seq_distance, columns=["seq1", "seq2","epitope_distance"])           
df_distance
# Out:
# 100% |########################################################################|
#                   seq1             seq2  epitope_distance
# 0      KF826828-A-2004  KF826827-A-2004          0.000000
# 1      KF826828-A-2004  KF530260-A-2005          0.072470
# 2      KF826828-A-2004  KF826838-A-2006          0.354667
# 3      KF826828-A-2004  KF826841-A-2007          0.000000
# 4      KF826828-A-2004  KF826846-A-2008          0.000000
# ...                ...              ...               ...
# 82616  AF035006_vaccin  RSVB_pda_ancest          7.746870
# 82617  AF035006_vaccin  RSVA_pda_ancest          1.122550
# 82618  KT992094_vaccin  RSVB_pda_ancest          7.746870
# 82619  KT992094_vaccin  RSVA_pda_ancest          1.122550
# 82620  RSVB_pda_ancest  RSVA_pda_ancest          6.624320
#
# [82621 rows x 3 columns]

# %%
def seq_mandist(df_epitope,epitope_feature):
    ## get sequence ID
    
    seq = df_epitope.ID.unique()
    ## loop through all seq in seq array to calculate Manhatton distance
    pbar = ProgressBar()
    seq_distance=[]
    for i in pbar(range(len(seq))):
        for j in range(len(seq)):
            if i<j:
                distance = cityblock(epitope_feature[seq[i]], epitope_feature[seq[j]])
                seq_distance.append([seq[i], seq[j], distance])                
                df_distance = pd.DataFrame(seq_distance, columns=["seq1", "seq2","epitope_distance"])
                    
    return(df_distance)
